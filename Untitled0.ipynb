# %%
import numpy as np
import pandas as pd
from PIL import Image

# %%
# %matplotlib inline

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
mpl.style.use('ggplot')

# %%
#!pip3 install wordcloud
from wordcloud import wordcloud ,STOPWORDS
print('sudah intal')
# Out:
# sudah intal

# %%
import urllib
bby= open ('/content/Chat WhatsApp dengan Violita ❤️.txt', mode='r').read()

# %%
stopwords = set(STOPWORDS)
print(len(stopwords))
# Out:
# 190

# %%
bby_wc = wordcloud(
    background_color = 'white',
    max_words = 2000,
    stopwords=stopwords
)
bby_wc.generate(bby)
